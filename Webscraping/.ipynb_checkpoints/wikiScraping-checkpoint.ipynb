# %%
# Importing relevant libraries
import requests as req
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
# Link to the wikipedia page with data required 
link = "https://en.wikipedia.org/wiki/Mountain_pigeon"

# Connect to the HTML page via the link and get content from the HTML page
response = req.get(link)
if response.status_code != 200:
    raise Exception(f"Failed to load page: {response.status_code}")
soup = BeautifulSoup(response.text, 'html.parser')

# %%
def get_article_titles(soup):
    """Finds all the article titles in the HTML page."""
    titles = [title.text.strip() for title in soup.find_all('h2')]
    print("Article Titles:")
    for title in titles:
        print(f"- {title}")
    return titles

# %%
def get_article_text(soup):
    """Extracts article text for each paragraph with their respective headings."""
    content = {}
    main_content = soup.find('div', {'id': 'bodyContent'})

    if main_content:
        for section in main_content.find_all(['h2', 'h3']):
            heading = section.text.strip()
            paragraphs = []
            for sibling in section.find_next_siblings():
                if sibling.name in ['h2', 'h3']:
                    break
                if sibling.name == 'p':
                    paragraphs.append(sibling.text.strip())
            content[heading] = ' '.join(paragraphs)
            print(f"\nHeading: {heading}")
            print(f"Content: {content[heading][:100]}...")  # Display first 100 characters
    return content

# %%
def extract_wikipedia_links(soup):
    """Collects all links that redirect to another Wikipedia page."""
    links = set()
    base_url = "https://en.wikipedia.org"
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        if href.startswith('/wiki/') and ':' not in href:  # Exclude special links like files
            full_url = urljoin(base_url, href)
            links.add(full_url)
    print("\nWikipedia Links:")
    for link in links:
        print(f"- {link}")
    return links

# %%
def scrape_wikipedia_page(soup):
    """Wraps all functions to scrape a Wikipedia page."""
    print("\nScraping Wikipedia Page...")
    return {
        "title": get_article_titles(soup),
        "text_by_heading": get_article_text(soup),
        "wikipedia_links": extract_wikipedia_links(soup)
    }

# %%
# Example usage
scraped_data = scrape_wikipedia_page(soup)
print("\nScraped Data:")
print(scraped_data)
# Out:
# Scraping Wikipedia Page...
# Article Titles:
# - Contents
# - Taxonomy and systematics
# - Description
# - Distribution and habitat
# - Behaviour and ecology
# - Status
# - Notes
# - References
#
# Heading: Taxonomy and systematics
# Content: ...
#
# Heading: List of species
# Content: ...
#
# Heading: Description
# Content: ...
#
# Heading: Vocalisations
# Content: ...
#
# Heading: Distribution and habitat
# Content: ...
#
# Heading: Behaviour and ecology
# Content: ...
#
# Heading: Feeding
# Content: ...
#
# Heading: Breeding
# Content: ...
#
# Heading: Predators and parasites
# Content: ...
#
# Heading: Status
# Content: ...
#
# Heading: Notes
# Content: ...
#
# Heading: References
# Content: ...
#
# Wikipedia Links:
# - https://en.wikipedia.org/wiki/Genus
# - https://en.wikipedia.org/wiki/Solomon_Islands_(archipelago)
# - https://en.wikipedia.org/wiki/Cladogram
# - https://en.wikipedia.org/wiki/Buff_(colour)
# - https://en.wikipedia.org/wiki/Underparts
# - https://en.wikipedia.org/wiki/Mesite
# - https://en.wikipedia.org/wiki/Blue_ground_dove
# - https://en.wikipedia.org/wiki/Internet_Archive
# - https://en.wikipedia.org/wiki/Frugivorous
# - https://en.wikipedia.org/wiki/Ducula
# - https://en.wikipedia.org/wiki/Neoaves
# - https://en.wikipedia.org/wiki/Mitochondrial_DNA
# - https://en.wikipedia.org/wiki/Tongoenas
# - https://en.wikipedia.org/wiki/Main_Page
# - https://en.wikipedia.org/wiki/Papuan_mountain_pigeon
# - https://en.wikipedia.org/wiki/Natunaornis
# - https://en.wikipedia.org/wiki/David_Gibbs_(naturalist)
# - https://en.wikipedia.org/wiki/Superspecies
# - https://en.wikipedia.org/wiki/Nesoenas
# - https://en.wikipedia.org/wiki/Geophaps
# - https://en.wikipedia.org/wiki/Syrrhaptes
# - https://en.wikipedia.org/wiki/Wine_(color)
# - https://en.wikipedia.org/wiki/Metriopelia
# - https://en.wikipedia.org/wiki/Petrophassa
# - https://en.wikipedia.org/wiki/Sandgrouse
# - https://en.wikipedia.org/wiki/Turtur
# - https://en.wikipedia.org/wiki/Clade
# - https://en.wikipedia.org/wiki/Coverts
# - https://en.wikipedia.org/wiki/OCLC_(identifier)
# - https://en.wikipedia.org/wiki/S2CID_(identifier)
# - https://en.wikipedia.org/wiki/Malaita
# - https://en.wikipedia.org/wiki/Lumpers_and_splitters
# - https://en.wikipedia.org/wiki/Parasitism
# - https://en.wikipedia.org/wiki/Pygmy_eagle
# - https://en.wikipedia.org/wiki/Least-concern_species
# - https://en.wikipedia.org/wiki/Lore_(anatomy)
# - https://en.wikipedia.org/wiki/Tommaso_Salvadori
# - https://en.wikipedia.org/wiki/Mesitornis
# - https://en.wikipedia.org/wiki/Taxonomic_sequence
# - https://en.wikipedia.org/wiki/Treron
# - https://en.wikipedia.org/wiki/Pigeon
# - https://en.wikipedia.org/wiki/Leucosarcia
# - https://en.wikipedia.org/wiki/Raphini
# - https://en.wikipedia.org/wiki/Bismarck_Archipelago
# - https://en.wikipedia.org/wiki/Ptilinopus
# - https://en.wikipedia.org/wiki/Reinwardtoena
# - https://en.wikipedia.org/wiki/Raphinae
# - https://en.wikipedia.org/wiki/Cryptophaps
# - https://en.wikipedia.org/wiki/Bird_colony
# - https://en.wikipedia.org/wiki/Oena
# - https://en.wikipedia.org/wiki/Tom_Iredale
# - https://en.wikipedia.org/wiki/Biodiversity_Heritage_Library
# - https://en.wikipedia.org/wiki/Canopy_(biology)
# - https://en.wikipedia.org/wiki/Melanesia
# - https://en.wikipedia.org/wiki/Otidiphaps
# - https://en.wikipedia.org/wiki/Maluku_Islands
# - https://en.wikipedia.org/wiki/Pterocles
# - https://en.wikipedia.org/wiki/Ornithologist
# - https://en.wikipedia.org/wiki/Wikidata
# - https://en.wikipedia.org/wiki/Yapen
# - https://en.wikipedia.org/wiki/Ernst_Mayr
# - https://en.wikipedia.org/wiki/Zentrygon
# - https://en.wikipedia.org/wiki/Wikispecies
# - https://en.wikipedia.org/wiki/Mountain_pigeon
# - https://en.wikipedia.org/wiki/Imperial_pigeon
# - https://en.wikipedia.org/wiki/Forktail_(journal)
# - https://en.wikipedia.org/wiki/Rupephaps
# - https://en.wikipedia.org/wiki/Taxonomy_(biology)
# - https://en.wikipedia.org/wiki/Cornell_Lab_of_Ornithology
# - https://en.wikipedia.org/wiki/Family_(biology)
# - https://en.wikipedia.org/wiki/Fruit_dove
# - https://en.wikipedia.org/wiki/Derek_Goodwin
# - https://en.wikipedia.org/wiki/Scientific_name
# - https://en.wikipedia.org/wiki/Princeton,_New_Jersey
# - https://en.wikipedia.org/wiki/Mesitornithiformes
# - https://en.wikipedia.org/wiki/Sociality
# - https://en.wikipedia.org/wiki/Dysmoropelia
# - https://en.wikipedia.org/wiki/Birds
# - https://en.wikipedia.org/wiki/Animal_Diversity_Web
# - https://en.wikipedia.org/wiki/Geopelia
# - https://en.wikipedia.org/wiki/Montane_forest
# - https://en.wikipedia.org/wiki/Turacoena
# - https://en.wikipedia.org/wiki/Zenaida_doves
# - https://en.wikipedia.org/wiki/Columbimorphae
# - https://en.wikipedia.org/wiki/Bacan_Islands
# - https://en.wikipedia.org/wiki/Emu_(journal)
# - https://en.wikipedia.org/wiki/Allopatric_speciation
# - https://en.wikipedia.org/wiki/Sister_group
# - https://en.wikipedia.org/wiki/Leptotrygon
# - https://en.wikipedia.org/wiki/Buru
# - https://en.wikipedia.org/wiki/Hdl_(identifier)
# - https://en.wikipedia.org/wiki/Bountyphaps
# - https://en.wikipedia.org/wiki/Guadalcanal
# - https://en.wikipedia.org/wiki/Buru_mountain_pigeon
# - https://en.wikipedia.org/wiki/Henicophaps
# - https://en.wikipedia.org/wiki/D%27Entrecasteaux_Islands
# - https://en.wikipedia.org/wiki/Caloenas
# - https://en.wikipedia.org/wiki/Doi_(identifier)
# - https://en.wikipedia.org/wiki/Ectopistes
# - https://en.wikipedia.org/wiki/Flock_(birds)
# - https://en.wikipedia.org/wiki/Forest_floor
# - https://en.wikipedia.org/wiki/Catalogue_of_Life
# - https://en.wikipedia.org/wiki/Columbidae
# - https://en.wikipedia.org/wiki/James_A._Jobling
# - https://en.wikipedia.org/wiki/Primophaps
# - https://en.wikipedia.org/wiki/Spilopelia
# - https://en.wikipedia.org/wiki/Binomial_authority
# - https://en.wikipedia.org/wiki/Geotrygon
# - https://en.wikipedia.org/wiki/Pezophaps
# - https://en.wikipedia.org/wiki/Journal_of_Natural_History
# - https://en.wikipedia.org/wiki/Ptilinopinae
# - https://en.wikipedia.org/wiki/Arenicolumba
# - https://en.wikipedia.org/wiki/Pteroclimesites
# - https://en.wikipedia.org/wiki/Uropelia
# - https://en.wikipedia.org/wiki/Kolombangara
# - https://en.wikipedia.org/wiki/Upperparts
# - https://en.wikipedia.org/wiki/Phaps
# - https://en.wikipedia.org/wiki/Gymnophaps_albertisii
# - https://en.wikipedia.org/wiki/Mesitornithidae
# - https://en.wikipedia.org/wiki/INaturalist
# - https://en.wikipedia.org/wiki/Topknot_pigeon
# - https://en.wikipedia.org/wiki/New_Guinea
# - https://en.wikipedia.org/wiki/Indonesia
# - https://en.wikipedia.org/wiki/Microgoura
# - https://en.wikipedia.org/wiki/Drupe
# - https://en.wikipedia.org/wiki/Cloven-feathered_dove
# - https://en.wikipedia.org/wiki/Vangunu
# - https://en.wikipedia.org/wiki/Integrated_Taxonomic_Information_System
# - https://en.wikipedia.org/wiki/Seram_Island
# - https://en.wikipedia.org/wiki/Chordate
# - https://en.wikipedia.org/wiki/Bird
# - https://en.wikipedia.org/wiki/IUCN_Red_List
# - https://en.wikipedia.org/wiki/Nuclear_DNA
# - https://en.wikipedia.org/wiki/Communal_roosting
# - https://en.wikipedia.org/wiki/Paraclaravis
# - https://en.wikipedia.org/wiki/Glossary_of_bird_terms#mantle
# - https://en.wikipedia.org/wiki/Columbina_(bird)
# - https://en.wikipedia.org/wiki/Australian_Field_Ornithology
# - https://en.wikipedia.org/wiki/Advertising_in_biology
# - https://en.wikipedia.org/wiki/Beech
# - https://en.wikipedia.org/wiki/Pica_Press
# - https://en.wikipedia.org/wiki/William_Ogilvie-Grant
# - https://en.wikipedia.org/wiki/Bibcode_(identifier)
# - https://en.wikipedia.org/wiki/Bougainville_Island
# - https://en.wikipedia.org/wiki/British_Ornithologists%27_Union
# - https://en.wikipedia.org/wiki/Goura_(genus)
# - https://en.wikipedia.org/wiki/ISBN_(identifier)
# - https://en.wikipedia.org/wiki/Gregory_Mathews
# - https://en.wikipedia.org/wiki/Starnoenas
# - https://en.wikipedia.org/wiki/Columbiformes
# - https://en.wikipedia.org/wiki/Species
# - https://en.wikipedia.org/wiki/Leptotila
# - https://en.wikipedia.org/wiki/Alectroenas
# - https://en.wikipedia.org/wiki/Pterocliformes
# - https://en.wikipedia.org/wiki/Rainy_season
# - https://en.wikipedia.org/wiki/International_Union_for_Conservation_of_Nature
# - https://en.wikipedia.org/wiki/Feather_louse
# - https://en.wikipedia.org/wiki/Ernst_Hartert
# - https://en.wikipedia.org/wiki/Pteroclidae
# - https://en.wikipedia.org/wiki/Dodo
# - https://en.wikipedia.org/wiki/Global_Biodiversity_Information_Facility
# - https://en.wikipedia.org/wiki/Orbit_(anatomy)
# - https://en.wikipedia.org/wiki/Pale_mountain_pigeon
# - https://en.wikipedia.org/wiki/Ficus
# - https://en.wikipedia.org/wiki/Glossary_of_bird_terms#upperparts
# - https://en.wikipedia.org/wiki/Lopholaimus
# - https://en.wikipedia.org/wiki/Pampusana
# - https://en.wikipedia.org/wiki/Columbinae
# - https://en.wikipedia.org/wiki/Type_species
# - https://en.wikipedia.org/wiki/Species_description
# - https://en.wikipedia.org/wiki/Basal_(phylogenetics)
# - https://en.wikipedia.org/wiki/Columba_(bird)
# - https://en.wikipedia.org/wiki/Arboreal_locomotion
# - https://en.wikipedia.org/wiki/Endemism
# - https://en.wikipedia.org/wiki/Drepanoptila
# - https://en.wikipedia.org/wiki/New_Britain
# - https://en.wikipedia.org/wiki/Sexual_dimorphism
# - https://en.wikipedia.org/wiki/National_Center_for_Biotechnology_Information
# - https://en.wikipedia.org/wiki/Schrader_Range
# - https://en.wikipedia.org/wiki/Animal
# - https://en.wikipedia.org/wiki/Gregarious
# - https://en.wikipedia.org/wiki/Macropygia
# - https://en.wikipedia.org/wiki/Eukaryote
# - https://en.wikipedia.org/wiki/ISSN_(identifier)
# - https://en.wikipedia.org/wiki/Streptopelia
# - https://en.wikipedia.org/wiki/PMID_(identifier)
# - https://en.wikipedia.org/wiki/Eating_soil
# - https://en.wikipedia.org/wiki/New_Ireland_(island)
# - https://en.wikipedia.org/wiki/Princeton_University_Press
# - https://en.wikipedia.org/wiki/Patagioenas
# - https://en.wikipedia.org/wiki/Monias
# - https://en.wikipedia.org/wiki/Montane_Forest
# - https://en.wikipedia.org/wiki/Clutch_(eggs)
# - https://en.wikipedia.org/wiki/Interim_Register_of_Marine_and_Nonmarine_Genera
# - https://en.wikipedia.org/wiki/Arboreal
# - https://en.wikipedia.org/wiki/American_Museum_Novitates
# - https://en.wikipedia.org/wiki/Hemiphaga
# - https://en.wikipedia.org/wiki/Phapitreron
# - https://en.wikipedia.org/wiki/Ancient_Greek
# - https://en.wikipedia.org/wiki/Bruce_Beehler
# - https://en.wikipedia.org/wiki/Linxiavis
# - https://en.wikipedia.org/wiki/Understory
# - https://en.wikipedia.org/wiki/Trugon
# - https://en.wikipedia.org/wiki/Seram_mountain_pigeon
# - https://en.wikipedia.org/wiki/Glossary_of_bird_terms#vent
# - https://en.wikipedia.org/wiki/Chalcophaps
# - https://en.wikipedia.org/wiki/Gallicolumba
# - https://en.wikipedia.org/wiki/Didunculus
# - https://en.wikipedia.org/wiki/Ocyphaps
# - https://en.wikipedia.org/wiki/Frugivore
# - https://en.wikipedia.org/wiki/Ibis_(journal)
#
# Scraped Data:
# {'title': ['Contents', 'Taxonomy and systematics', 'Description', 'Distribution and habitat', 'Behaviour and ecology', 'Status', 'Notes', 'References'], 'text_by_heading': {'Taxonomy and systematics': '', 'List of species': '', 'Description': '', 'Vocalisations': '', 'Distribution and habitat': '', 'Behaviour and ecology': '', 'Feeding': '', 'Breeding': '', 'Predators and parasites': '', 'Status': '', 'Notes': '', 'References': ''}, 'wikipedia_links': {'https://en.wikipedia.org/wiki/Genus', 'https://en.wikipedia.org/wiki/Solomon_Islands_(archipelago)', 'https://en.wikipedia.org/wiki/Cladogram', 'https://en.wikipedia.org/wiki/Buff_(colour)', 'https://en.wikipedia.org/wiki/Underparts', 'https://en.wikipedia.org/wiki/Mesite', 'https://en.wikipedia.org/wiki/Blue_ground_dove', 'https://en.wikipedia.org/wiki/Internet_Archive', 'https://en.wikipedia.org/wiki/Frugivorous', 'https://en.wikipedia.org/wiki/Ducula', 'https://en.wikipedia.org/wiki/Neoaves', 'https://en.wikipedia.org/wiki/Mitochondrial_DNA', 'https://en.wikipedia.org/wiki/Tongoenas', 'https://en.wikipedia.org/wiki/Main_Page', 'https://en.wikipedia.org/wiki/Papuan_mountain_pigeon', 'https://en.wikipedia.org/wiki/Natunaornis', 'https://en.wikipedia.org/wiki/David_Gibbs_(naturalist)', 'https://en.wikipedia.org/wiki/Superspecies', 'https://en.wikipedia.org/wiki/Nesoenas', 'https://en.wikipedia.org/wiki/Geophaps', 'https://en.wikipedia.org/wiki/Syrrhaptes', 'https://en.wikipedia.org/wiki/Wine_(color)', 'https://en.wikipedia.org/wiki/Metriopelia', 'https://en.wikipedia.org/wiki/Petrophassa', 'https://en.wikipedia.org/wiki/Sandgrouse', 'https://en.wikipedia.org/wiki/Turtur', 'https://en.wikipedia.org/wiki/Clade', 'https://en.wikipedia.org/wiki/Coverts', 'https://en.wikipedia.org/wiki/OCLC_(identifier)', 'https://en.wikipedia.org/wiki/S2CID_(identifier)', 'https://en.wikipedia.org/wiki/Malaita', 'https://en.wikipedia.org/wiki/Lumpers_and_splitters', 'https://en.wikipedia.org/wiki/Parasitism', 'https://en.wikipedia.org/wiki/Pygmy_eagle', 'https://en.wikipedia.org/wiki/Least-concern_species', 'https://en.wikipedia.org/wiki/Lore_(anatomy)', 'https://en.wikipedia.org/wiki/Tommaso_Salvadori', 'https://en.wikipedia.org/wiki/Mesitornis', 'https://en.wikipedia.org/wiki/Taxonomic_sequence', 'https://en.wikipedia.org/wiki/Treron', 'https://en.wikipedia.org/wiki/Pigeon', 'https://en.wikipedia.org/wiki/Leucosarcia', 'https://en.wikipedia.org/wiki/Raphini', 'https://en.wikipedia.org/wiki/Bismarck_Archipelago', 'https://en.wikipedia.org/wiki/Ptilinopus', 'https://en.wikipedia.org/wiki/Reinwardtoena', 'https://en.wikipedia.org/wiki/Raphinae', 'https://en.wikipedia.org/wiki/Cryptophaps', 'https://en.wikipedia.org/wiki/Bird_colony', 'https://en.wikipedia.org/wiki/Oena', 'https://en.wikipedia.org/wiki/Tom_Iredale', 'https://en.wikipedia.org/wiki/Biodiversity_Heritage_Library', 'https://en.wikipedia.org/wiki/Canopy_(biology)', 'https://en.wikipedia.org/wiki/Melanesia', 'https://en.wikipedia.org/wiki/Otidiphaps', 'https://en.wikipedia.org/wiki/Maluku_Islands', 'https://en.wikipedia.org/wiki/Pterocles', 'https://en.wikipedia.org/wiki/Ornithologist', 'https://en.wikipedia.org/wiki/Wikidata', 'https://en.wikipedia.org/wiki/Yapen', 'https://en.wikipedia.org/wiki/Ernst_Mayr', 'https://en.wikipedia.org/wiki/Zentrygon', 'https://en.wikipedia.org/wiki/Wikispecies', 'https://en.wikipedia.org/wiki/Mountain_pigeon', 'https://en.wikipedia.org/wiki/Imperial_pigeon', 'https://en.wikipedia.org/wiki/Forktail_(journal)', 'https://en.wikipedia.org/wiki/Rupephaps', 'https://en.wikipedia.org/wiki/Taxonomy_(biology)', 'https://en.wikipedia.org/wiki/Cornell_Lab_of_Ornithology', 'https://en.wikipedia.org/wiki/Family_(biology)', 'https://en.wikipedia.org/wiki/Fruit_dove', 'https://en.wikipedia.org/wiki/Derek_Goodwin', 'https://en.wikipedia.org/wiki/Scientific_name', 'https://en.wikipedia.org/wiki/Princeton,_New_Jersey', 'https://en.wikipedia.org/wiki/Mesitornithiformes', 'https://en.wikipedia.org/wiki/Sociality', 'https://en ...
