# %%
# importing relevant libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# file path to the dataset
file_path = "./da441665-2c6b-4943-97ff-b2210638de83.csv"
# creating a dataframe
df = pd.read_csv(file_path)
df.head()
# Out:
#    Temperature  Humidity  WindSpeed  AtmosphericPressure  Rainfall
# 0         25.3        78       12.5               1013.2       0.0
# 1         23.8        85        8.2               1012.8       2.5
# 2         22.1        90       15.6               1010.5       8.3
# 3         26.4        65       10.3               1015.6       0.0
# 4         24.7        82        9.8               1014.2       1.2

# %%
# removing null values
df.dropna()
# Out:
#     Temperature  Humidity  WindSpeed  AtmosphericPressure  Rainfall
# 0          25.3        78       12.5               1013.2       0.0
# 1          23.8        85        8.2               1012.8       2.5
# 2          22.1        90       15.6               1010.5       8.3
# 3          26.4        65       10.3               1015.6       0.0
# 4          24.7        82        9.8               1014.2       1.2
# 5          28.5        70       11.4               1013.8       0.0
# 6          21.9        88       14.7               1009.6      12.5
# 7          27.2        75        7.9               1014.8       0.0
# 8          25.8        80       13.2               1012.4       3.8
# 9          29.1        68        9.5               1015.2       0.0
# 10         22.5        92       16.8               1008.9      15.7
# 11         26.8        72        8.8               1014.5       0.0
# 12         24.3        83       12.1               1011.8       4.2
# 13         27.9        71       10.7               1013.5       0.0
# 14         23.2        87       15.3               1010.2       7.8
# 15         28.7        69        9.1               1015.4       0.0
# 16         25.1        81       11.8               1012.9       2.1
# 17         26.5        76       13.5               1013.1       1.5
# 18         22.8        89       14.2               1009.8       9.6
# 19         27.5        73        8.5               1014.7       0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperature          20 non-null     float64
#  1   Humidity             20 non-null     int64
#  2   WindSpeed            20 non-null     float64
#  3   AtmosphericPressure  20 non-null     float64
#  4   Rainfall             20 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 932.0 bytes

# %%
# to predict rainfall rate
# obtain the features and targets
features =['Temperature','Humidity','WindSpeed','AtmosphericPressure']
target = 'Rainfall'

x = df[features]
y = df[target]

# %%
# Training and testing the model
x_train,x_test,y_train,y_test = train_test_split(x ,y , test_size = 0.2 , random_state = 42)

# %%
# create the model
model = LinearRegression()

# test the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[23.5,85,10.8,1010.7]])[0]
# Out:
# \\?\C:\Users\ISAIAH\AppData\Roaming\jupyterlab-desktop\envs\data_science_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(8.121063985903447)
